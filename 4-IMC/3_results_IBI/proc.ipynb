# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pairing = {
    0: "Na_Na",
    1: "Cl_Cl",
    2: "Na_Cl"
        }

# %%
r, V = np.loadtxt("final_Na_Na.txt", unpack=True)

# %%
plt.plot(r[30:], V[30:], )
#plt.ylim(np.min(V), 5)
