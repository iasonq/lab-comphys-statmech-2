# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pairing = {
    0: "Na_Na",
    1: "Cl_Cl",
    2: "Na_Cl"
        }

# %%
r, V = np.loadtxt("final_Na_Cl.txt", unpack=True)

# %%
plt.plot(r[50:], V[50:], )
plt.ylim(np.min(V), 5)
# Out:
# (-19.1560106, 5.0)
